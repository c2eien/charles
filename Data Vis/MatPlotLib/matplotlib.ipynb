# %%
# first install to machine using "pip install matpliblib" 
#or "conda install matplotlib"
#see matploblib website for more info

#then import to environment:
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
#for jupyter notebook, allows plots to show in notebook
#(if not using jupyter notebook, use "plt.show()" to return/print plot)

# call a fig object to show it (just type "<figurename>")

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x **2
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
# two ways to create plots: FUNCTIONAL or OBJECT-ORIENTED
#(OBJECT-ORIENTED is better?)

# %% [markdown]
# ## FUNCTIONAL

# %%
plt.plot(x,y)
#use plt.show() to return/print; 
#for jupyter notebook, once "%matplotlib inline" is specified, 
#plt.show is not necessary

plt.xlabel('X label')
plt.ylabel('Y Label')
plt.title('TITLE')

# %%
#to create MULTIPLE PLOTS on SAME CANVAS

plt.subplot(1, 2, 1)
# (num of rows, num of columns, plot column)
plt.plot(x,y, 'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# ## OBJECT-ORIENTED API METHOD
# Instantiate the figure objects and then call methods or attributes off that object  (axes, plot, title, etc)

# %%
fig = plt.figure()  # create a figure object  (like a canvas)

axes = fig.add_axes([0.1,0.1, 0.8, 0.8])  #create axes object for figure
#([left, bottom, width, height])
# The left and bottom do not refer to the rectangle's dimensions. 
#They refer to the 'canvas'. 
#When you create just one axes object (just one rectangle) 
#it won't matter what the left and bottom parameters are.

axes.plot(x,y,label='line x')
axes.plot(x**2,y,label='line x^2')
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('SET TITLE')
axes.legend(loc=0) #see location codes for legends; 0 is 'best'

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.9,0.9])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])

# The left and bottom do not refer to the rectangle's dimensions. 
#They refer to the 'canvas'. 
#When you create just one axes object (just one rectangle) 
#it won't matter what the left and bottom parameters are.

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')

# %% [markdown]
# ### Alternative to "add_axes", can use  subplots
# ### to set up figure with axes at the same time:

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# plt.subplots basically instantiates the "figure" 
#and does the 'add_axes' method based on the rows and columns specified

# the first assignment ("fig") is for the whole figure
# the second assignment ("axes") willg et an array of each axes/subplot

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()   #this prevents overlapping of plots

# %%
# can iterate on axes, since it's an array
fig1,axes1 = plt.subplots(nrows=2,ncols=2)
for i in axes1:
    for j in i:
        j.plot(x,y)

#note: had to have a nested iteration, since it's a 2-d array

# %%
fig2,axes2 = plt.subplots(nrows=2,ncols=2)
for indi, i in enumerate(axes2):  
    #enumerate allows you to get the index of the for loop 
    #(Assigned "indi" here)  ("i" is the actual value in the axes array)
    for indj, j in enumerate(i):
        j.plot(x,y)
        j.set_title(str(indi)+"-"+str(indj))
        
plt.tight_layout()   #this prevents overlapping of plots

# %% [markdown]
# ### Figure Size and DPI

# %%
fig4 = plt.figure(figsize=(3,2),dpi=100) #DPI is pixels per inch
ax4 = fig4.add_axes([0,0,1,1])
ax4.plot(x,y)

# %%
fig5,ax5 = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
ax5[0].plot(x,y)
ax5[1].plot(y,x)
plt.tight_layout()

# %% [markdown]
# ### Saving Figures

# %%
fig5.savefig('my_pic.png') 
#pass the desired extension in the method input (e.g., png, jpg, etc)
#can specify dpi if you want

# %% [markdown]
# ### Plot Appearance

# %%
fig6=plt.figure()
ax6 = fig6.add_axes([0,0,1,1])
ax6.plot(x,y, color='red', lw=5, alpha = 0.5, ls='-.', marker='x', ms=10) 
ax6.plot(y,x, marker ='o', ms=10)

# line color, linewidth (lw), transparency (alpha), linestyle (ls), 
# marker (specific points), markersize (ms)
# and there's a lot more - just see documentation or jupyter notebook

ax6.set_xlim([0,10])
ax6.set_ylim([0,10])    # to set plot boundaries
# Out:
# (0, 10)

# %% [markdown]
# # More Helpful References
# https://www.labri.fr/perso/nrougier/teaching/matplotlib/
#
# https://matplotlib.org/gallery.html
